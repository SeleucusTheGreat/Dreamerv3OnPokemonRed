# %% [markdown]
# ### Testing Loop

# %%
import torch
from PokemonRedEnv import create_envs
from policy import Policy

RUN_MODE = "train" #train or eval
ROM_PATH = "PokemonRed.gb"
NUM_EVAL_EPISODES = 1
NUM_ENVS = 5
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.32.0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

envs = create_envs(num_envs=NUM_ENVS, rom_path=ROM_PATH, state_dir="StartingFiles",wind="null")# <---------------------"SDL2" or "null"
print("Initializing Dreamer Policy...")
policy = Policy(envs=envs, device=device, visualize_dreams=True)

if RUN_MODE == "train":
    
    print("Starting Training Mode...")
    policy.train()




elif RUN_MODE == "eval":
    print("Starting Evaluation Mode...")
    policy.evaluate(num_episodes=NUM_EVAL_EPISODES)
else:
    print(f"Invalid RUN_MODE: '{RUN_MODE}'. Please set it to 'train' or 'eval'.") 

envs.close()
print("All environments safely closed.")
# Out:
# Using device: cuda
# Initializing 5 PyBoy Environments (all using PokemonRed.Start.state, parallel=True)...
# Initializing Dreamer Policy...
# Starting Training Mode...
# Loading replay buffer...
# [*] Loaded buffer with 1000000 transitions (full=True, write_head=0, reward_positions=139, curiosity_positions=217)
# [*] Recovered CSV Progress: 54192500 Env Steps | 237000 Gradient Steps
#
# ==================================================
# [*] Replay buffer already contains data. Skipping initial environment collection.
# ==================================================
#
# [*] Starting Training Loop...
#
# --------------------------------------------------
# --- Training Episode 1 / 10000 ---
#     [Training] Step 0 / 500
#     [Training] Step 50 / 500
#     [Training] Step 100 / 500
#     [Training] Step 150 / 500
#     [Training] Step 200 / 500
#     [Training] Step 250 / 500
#     [Training] Step 300 / 500
#     [Training] Step 350 / 500
#     [Training] Step 400 / 500
#     [Training] Step 450 / 500
# [*] Saving 5 MAX ADVANTAGE Dreams (Cumulative Advs: [+3.89, +3.16, +4.78, +9.36, +2.64])
# [*] Saving 5 RANDOM Dreams (Cumulative Advs: [+1.02, +0.46, +0.12, +0.78, +0.01])
# [*] Saving 5 MAX CURIOSITY Dreams (Cumulative Curiosity: [+1.84, +1.68, +1.40, +1.39, +1.34])
# [*] Saved 15 dreams to dreams\dream_g237500.pdf
# [*] Stepping environment with updated policy...
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [LEVEL] +20.000 | Total Party Level up to: 8
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 3] [EVENT] +50.000 | Budget: 22500
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 2 (LTM idx 1450)
#     [Env 4] [EVENT] +50.000 | Budget: 22500
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 5] [EVENT] +50.000 | Budget: 22500
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 5] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 3] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 3] [EVENT] +50.000 | Budget: 27500
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 4] [EVENT] +50.000 | Budget: 25000
#     [Env 3] >>> [GYM ENTERED] +5.0 | Pewter Gym <<<
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 4] [EVENT] +50.000 | Budget: 27500
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 4] [EVENT] +50.000 | Budget: 30000
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 11
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 1] [EVENT] +50.000 | Budget: 22500
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 12
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 2 (LTM idx 1450)
#     [Env 1] [EVENT] +50.000 | Budget: 25000
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 1] [EVENT] +50.000 | Budget: 27500
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 1] [EVENT] +50.000 | Budget: 30000
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 1] >>> [GYM ENTERED] +5.0 | Pewter Gym <<<
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 13
#     [Env 2] Episode done | Reward: 30.23 | Curiosity: 18.220 | Unique maps visited: 9 [0, 1, 12, 13, 33, 37, 38, 50, 51]
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 14
#     [Env 5] Episode done | Reward: 130.54 | Curiosity: 20.240 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 53]
#     [Env 3] Episode done | Reward: 200.62 | Curiosity: 25.490 | Unique maps visited: 15 [0, 1, 2, 12, 13, 33, 37, 38, 39, 47, 50, 51, 52, 53, 54]
#     [Env 1] Episode done | Reward: 294.46 | Curiosity: 30.450 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 54]
#     [Env 4] Episode done | Reward: 251.24 | Curiosity: 21.640 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 53]
#
# ==================================================
#           REPLAY BUFFER DIAGNOSTICS
# ==================================================
#   Buffer Fill : 1,000,000 / 1,000,000 (100.00%)
#   Active Environments : 5
#   Recent Sampling Window Size : 100,000 steps
# ==================================================
#
#     > Total Env Steps : 54325000
#     > Gradient Steps  : 237500
#     > Total Reward    : 181.42
#     > Total Curiosity : 23.2080
#     > Actor Entropy   : 0.7943
#     > Mean dream curiosity: 0.0043
#
# --------------------------------------------------
# --- Training Episode 2 / 10000 ---
#     [Training] Step 0 / 500
#     [Training] Step 50 / 500
#     [Training] Step 100 / 500
#     [Training] Step 150 / 500
#     [Training] Step 200 / 500
#     [Training] Step 250 / 500
#     [Training] Step 300 / 500
#     [Training] Step 350 / 500
#     [Training] Step 400 / 500
#     [Training] Step 450 / 500
# [*] Saving 5 MAX ADVANTAGE Dreams (Cumulative Advs: [+3.32, +4.66, +2.67, +4.90, +7.04])
# [*] Saving 5 RANDOM Dreams (Cumulative Advs: [+0.16, -0.06, +0.37, +0.34, -0.22])
# [*] Saving 5 MAX CURIOSITY Dreams (Cumulative Curiosity: [+1.79, +1.35, +1.27, +1.21, +1.06])
# [*] Saved 15 dreams to dreams\dream_g238000.pdf
# [*] Stepping environment with updated policy...
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 5] [EVENT] +50.000 | Budget: 22500
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 5] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [LEVEL] +20.000 | Total Party Level up to: 8
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 3] [EVENT] +50.000 | Budget: 22500
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 3] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 2] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 2 (LTM idx 1450)
#     [Env 2] [EVENT] +50.000 | Budget: 22500
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 4] [EVENT] +50.000 | Budget: 22500
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 4] [EVENT] +50.000 | Budget: 25000
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 2] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 2] [EVENT] +50.000 | Budget: 25000
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 2] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 2] [EVENT] +50.000 | Budget: 27500
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 1] [EVENT] +50.000 | Budget: 22500
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 1] [EVENT] +50.000 | Budget: 25000
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 1] [EVENT] +50.000 | Budget: 27500
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 11
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 11
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 12
#     [Env 3] Episode done | Reward: 171.60 | Curiosity: 19.840 | Unique maps visited: 12 [0, 1, 2, 12, 13, 33, 37, 38, 40, 47, 50, 51]
#     [Env 4] Episode done | Reward: 140.91 | Curiosity: 24.870 | Unique maps visited: 15 [0, 1, 2, 12, 13, 33, 37, 38, 40, 43, 47, 50, 51, 52, 56]
#     [Env 5] Episode done | Reward: 120.64 | Curiosity: 21.170 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 42, 47, 50, 51, 52]
#     [Env 1] Episode done | Reward: 211.74 | Curiosity: 22.570 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 40, 47, 50, 51, 52]
#     [Env 2] Episode done | Reward: 200.94 | Curiosity: 22.350 | Unique maps visited: 16 [0, 1, 2, 12, 13, 33, 37, 38, 39, 40, 47, 50, 51, 52, 55, 56]
#
# ==================================================
#           REPLAY BUFFER DIAGNOSTICS
# ==================================================
#   Buffer Fill : 1,000,000 / 1,000,000 (100.00%)
#   Active Environments : 5
#   Recent Sampling Window Size : 100,000 steps
# ==================================================
#
#     > Total Env Steps : 54455000
#     > Gradient Steps  : 238000
#     > Total Reward    : 169.16
#     > Total Curiosity : 22.1600
#     > Actor Entropy   : 0.8157
#     > Mean dream curiosity: 0.0056
#
# --------------------------------------------------
# --- Training Episode 3 / 10000 ---
#     [Training] Step 0 / 500
#     [Training] Step 50 / 500
#     [Training] Step 100 / 500
#     [Training] Step 150 / 500
#     [Training] Step 200 / 500
#     [Training] Step 250 / 500
#     [Training] Step 300 / 500
#     [Training] Step 350 / 500
#     [Training] Step 400 / 500
#     [Training] Step 450 / 500
# [*] Saving 5 MAX ADVANTAGE Dreams (Cumulative Advs: [+7.28, +7.81, +4.38, +4.13, +7.10])
# [*] Saving 5 RANDOM Dreams (Cumulative Advs: [+0.31, -0.06, +0.33, +0.15, +0.09])
# [*] Saving 5 MAX CURIOSITY Dreams (Cumulative Curiosity: [+2.00, +1.96, +1.86, +1.38, +1.35])
# [*] Saved 15 dreams to dreams\dream_g238500.pdf
# [*] Stepping environment with updated policy...
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 5] [LEVEL] +20.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 5] [EVENT] +50.000 | Budget: 22500
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 5] [EVENT] +50.000 | Budget: 25000
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 5] [EVENT] +50.000 | Budget: 27500
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 2 (LTM idx 1450)
#     [Env 1] [EVENT] +50.000 | Budget: 22500
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 1] [EVENT] +50.000 | Budget: 25000
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 1] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 1] [EVENT] +50.000 | Budget: 27500
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 2] Episode done | Reward: 21.02 | Curiosity: 13.920 | Unique maps visited: 10 [0, 1, 12, 13, 33, 37, 38, 40, 50, 51]
#     [Env 3] Episode done | Reward: 24.99 | Curiosity: 12.880 | Unique maps visited: 9 [0, 1, 12, 13, 33, 37, 38, 50, 51]
#     [Env 4] Episode done | Reward: 55.82 | Curiosity: 11.370 | Unique maps visited: 10 [0, 1, 12, 13, 33, 37, 38, 40, 50, 51]
#     [Env 1] [LEVEL] +10.000 | Total Party Level up to: 11
#     [Env 1] Episode done | Reward: 210.97 | Curiosity: 18.570 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 55]
#     [Env 5] Episode done | Reward: 190.28 | Curiosity: 14.940 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 55]
#
# ==================================================
#           REPLAY BUFFER DIAGNOSTICS
# ==================================================
#   Buffer Fill : 1,000,000 / 1,000,000 (100.00%)
#   Active Environments : 5
#   Recent Sampling Window Size : 100,000 steps
# ==================================================
#
#     > Total Env Steps : 54570000
#     > Gradient Steps  : 238500
#     > Total Reward    : 100.61
#     > Total Curiosity : 14.3360
#     > Actor Entropy   : 0.6890
#     > Mean dream curiosity: 0.0049
# Saved checkpoint: checkpoints\pokemon_model_R100_G238500.pt
# Saving replay buffer...
#
# --------------------------------------------------
# --- Training Episode 4 / 10000 ---
#     [Training] Step 0 / 500
#     [Training] Step 50 / 500
#     [Training] Step 100 / 500
#     [Training] Step 150 / 500
#     [Training] Step 200 / 500
#     [Training] Step 250 / 500
#     [Training] Step 300 / 500
#     [Training] Step 350 / 500
#     [Training] Step 400 / 500
#     [Training] Step 450 / 500
# [*] Saving 5 MAX ADVANTAGE Dreams (Cumulative Advs: [+10.20, +8.16, +3.22, +5.38, +4.57])
# [*] Saving 5 RANDOM Dreams (Cumulative Advs: [+0.01, +0.01, +0.65, +0.95, +0.27])
# [*] Saving 5 MAX CURIOSITY Dreams (Cumulative Curiosity: [+3.87, +3.84, +2.81, +2.68, +2.46])
# [*] Saved 15 dreams to dreams\dream_g239000.pdf
# [*] Stepping environment with updated policy...
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 1
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian City
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 22
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 1] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Route 2
#     [Env 2] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 3] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Viridian Forest
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 7
#     [Env 2] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 2 (LTM idx 1450)
#     [Env 2] [EVENT] +50.000 | Budget: 22500
#     [Env 5] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 5] [EVENT] +50.000 | Budget: 22500
#     [Env 5] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 5] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 5] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 8
#     [Env 3] [LEVEL] +20.000 | Total Party Level up to: 8
#     [Env 4] [LEVEL] +10.000 | Total Party Level up to: 6
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 4 (LTM idx 1452)
#     [Env 4] [EVENT] +50.000 | Budget: 22500
#     [Env 3] [EVENT REWARD] Triggered by Memory Address: 0xd7f3, Bit: 3 (LTM idx 1451)
#     [Env 3] [EVENT] +50.000 | Budget: 22500
#     [Env 4] [CURIOSITY BONUS] +1.0 awarded for transitioning to Pewter City
#     [Env 4] [EVENT REWARD] Triggered by Memory Address: 0xd754, Bit: 0 (LTM idx 176)
#     [Env 4] [EVENT] +50.000 | Budget: 25000
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 9
#     [Env 3] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 2] [LEVEL] +10.000 | Total Party Level up to: 10
#     [Env 1] Episode done | Reward: 4.21 | Curiosity: 15.100 | Unique maps visited: 9 [0, 1, 12, 13, 33, 37, 38, 50, 51]
#     [Env 2] Episode done | Reward: 101.19 | Curiosity: 10.930 | Unique maps visited: 9 [0, 1, 12, 13, 33, 37, 38, 50, 51]
#     [Env 3] Episode done | Reward: 100.50 | Curiosity: 14.410 | Unique maps visited: 10 [0, 1, 12, 13, 33, 37, 38, 40, 50, 51]
#     [Env 4] Episode done | Reward: 110.17 | Curiosity: 18.150 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 55]
#     [Env 5] Episode done | Reward: 110.13 | Curiosity: 14.710 | Unique maps visited: 13 [0, 1, 2, 12, 13, 33, 37, 38, 47, 50, 51, 52, 55]
#
# ==================================================
#           REPLAY BUFFER DIAGNOSTICS
# ==================================================
#   Buffer Fill : 1,000,000 / 1,000,000 (100.00%)
#   Active Environments : 5
#   Recent Sampling Window Size : 100,000 steps
# ==================================================
#
#     > Total Env Steps : 54685000
#     > Gradient Steps  : 239000
#     > Total Reward    : 85.24
#     > Total Curiosity : 14.6600
#     > Actor Entropy   : 0.7330
#     > Mean dream curiosity: 0.0040
#
# --------------------------------------------------
# --- Training Episode 5 / 10000 ---
#     [Training] Step 0 / 500
#     [Training] Step 50 / 500
